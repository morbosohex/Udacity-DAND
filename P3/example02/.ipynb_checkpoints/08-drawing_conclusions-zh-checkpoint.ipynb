# %% [markdown]
# # 得出结论
# 使用下列空间来处理数据集`clean_08.csv` 和`clean_18.csv`中的以下问题

# %%
# load datasets
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df_08 = pd.read_csv('clean_08.csv')
df_18 = pd.read_csv('clean_18.csv')

# %%
df_08.head(1)
# Out:
#        model  displ  cyl    trans drive      fuel veh_class  \
# 0  ACURA MDX    3.7    6  Auto-S5   4WD  Gasoline       SUV
#
#    air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  greenhouse_gas_score  \
# 0                  7.0      15.0     20.0     17.0                     4
#
#   smartway
# 0       no

# %% [markdown]
# ### Q1: 是否有更多使用替代燃料来源的独特模式？ 具体多多少？

# %%
df_08['fuel'].value_counts()
# Out:
# Gasoline    984
# gas           1
# ethanol       1
# CNG           1
# Name: fuel, dtype: int64

# %%
df_18['fuel'].value_counts()
# Out:
# Gasoline       749
# Ethanol         26
# Gas             26
# Diesel          19
# Electricity     12
# Name: fuel, dtype: int64

# %%
alt_08 = df_08.query('fuel in ["ethanol","CNG"]').model.nunique()
alt_08
# Out:
# 2

# %%
alt_18 = df_18.query('fuel in ["Ethanol","Electricity"]').model.nunique()
alt_18
# Out:
# 26

# %%
plt.bar(["2008","2018"], [alt_08,alt_18])
plt.title("Number of Unique Models Using Alternatibe Fuels")
plt.xlabel("Year")
plt.ylabel("Number of Unique Models")
# Out:
# Text(0,0.5,'Number of Unique Models')

# %%
# total unique models each year
total_model_08 = df_08.model.nunique()
total_model_18 = df_18.model.nunique()

# %%
prop_08 = alt_08 / total_model_08
prop_18 = alt_18 / total_model_18

# %%
plt.bar(['2008','2018'],[prop_08, prop_18])
plt.title('Proportion of Unique Models')
plt.xlabel('Year')
plt.ylabel('Proportion of Unique Models')
# Out:
# Text(0,0.5,'Proportion of Unique Models')

# %% [markdown]
# ### Q2: 车辆级别在燃油经济性方面有多少改进？

# %%
veh_08 = df_08.groupby('veh_class').cmb_mpg.mean()
veh_08
# Out:
# veh_class
# SUV              18.471429
# large car        18.509091
# midsize car      21.601449
# minivan          19.117647
# pickup           16.277108
# small car        21.105105
# station wagon    22.366667
# van              14.952381
# Name: cmb_mpg, dtype: float64

# %%
veh_18 = df_18.groupby('veh_class').cmb_mpg.mean()
veh_18
# Out:
# veh_class
# large car          23.409091
# midsize car        27.884058
# minivan            20.800000
# pickup             18.589744
# small SUV          24.074074
# small car          25.421053
# special purpose    18.500000
# standard SUV       18.197674
# station wagon      27.529412
# Name: cmb_mpg, dtype: float64

# %%
# how much they've increased by for each vehicle class
inc = veh_18 - veh_08
inc
# Out:
# veh_class
# SUV                     NaN
# large car          4.900000
# midsize car        6.282609
# minivan            1.682353
# pickup             2.312635
# small SUV               NaN
# small car          4.315948
# special purpose         NaN
# standard SUV            NaN
# station wagon      5.162745
# van                     NaN
# Name: cmb_mpg, dtype: float64

# %%
# only plot the classes that exist in both years
inc.dropna(inplace=True)
plt.subplots(figsize=(8,5))
plt.bar(inc.index, inc)
plt.title('Improvements in Fuel Economy from 2008 to 2018 by Vehicle Class')
plt.xlabel('Vehicle Class')
plt.ylabel('Increase in Average Combined MPG')
# Out:
# Text(0,0.5,'Increase in Average Combined MPG')

# %% [markdown]
# ### Q3: SmartWay 车辆的特点是什么？ 它们是否随着时间而改变？

# %%
# get all smartway vehicles in 2008
smart_08 = df_08.query('smartway=="yes"')

# %%
smart_08.describe().mean()
# Out:
# displ                   49.650166
# cyl                     51.478543
# air_pollution_score     53.126748
# city_mpg                66.303360
# hwy_mpg                 70.311044
# cmb_mpg                 67.849653
# greenhouse_gas_score    52.961970
# dtype: float64

# %%
# smartway labels for 2018
df_18.smartway.unique()
# Out:
# array(['No', 'Yes', 'Elite'], dtype=object)

# %%
# get all smartway vehicles in 2018
smart_18 = df_18.query('smartway in ["Yes","Elite"]')

# %%
smart_18.describe().mean()
# Out:
# displ                   15.011999
# cyl                     16.668939
# air_pollution_score     18.753697
# city_mpg                48.136174
# hwy_mpg                 50.227182
# cmb_mpg                 48.776193
# greenhouse_gas_score    19.640413
# dtype: float64

# %%
diff = smart_18.describe().mean() - smart_08.describe().mean()
diff
# Out:
# displ                  -34.638167
# cyl                    -34.809603
# air_pollution_score    -34.373051
# city_mpg               -18.167187
# hwy_mpg                -20.083862
# cmb_mpg                -19.073460
# greenhouse_gas_score   -33.321557
# dtype: float64

# %%
plt.subplots(figsize=(8,5))
plt.bar(diff.index,diff)
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# ### Q4: 哪些功能与更好的燃油经济性有关？

# %%
top_08 = df_08.query('cmb_mpg > cmb_mpg.mean()')
top_08.describe()
# Out:
#             displ         cyl  air_pollution_score    city_mpg     hwy_mpg  \
# count  519.000000  519.000000           519.000000  519.000000  519.000000
# mean     2.667823    4.890173             6.998073   20.317919   27.603083
# std      0.665551    1.034856             1.159565    3.198257    3.051120
# min      1.300000    4.000000             4.000000   17.000000   20.000000
# 25%      2.300000    4.000000             6.000000   18.000000   25.000000
# 50%      2.500000    4.000000             7.000000   20.000000   27.000000
# 75%      3.000000    6.000000             7.000000   21.000000   29.000000
# max      6.000000    8.000000             9.500000   48.000000   45.000000
#
#           cmb_mpg  greenhouse_gas_score
# count  519.000000            519.000000
# mean    22.992293              6.639692
# std      2.926371              0.804935
# min     20.000000              6.000000
# 25%     21.000000              6.000000
# 50%     22.000000              6.000000
# ...

# %%
pd.plotting.scatter_matrix(top_08,figsize=(15,15));

# %%
top_18 = df_18.query('cmb_mpg > cmb_mpg.mean()')
top_18.describe().mean()
# Out:
#             displ         cyl  air_pollution_score    city_mpg     hwy_mpg  \
# count  328.000000  328.000000           328.000000  328.000000  328.000000
# mean     1.964329    4.021341             6.669207   27.472561   35.304878
# std      0.398593    0.465477             0.963174   11.033692    9.024857
# min      1.200000    3.000000             6.000000   21.000000   27.000000
# 25%      1.600000    4.000000             6.000000   23.000000   31.000000
# 50%      2.000000    4.000000             6.000000   25.000000   33.000000
# 75%      2.000000    4.000000             7.000000   28.000000   36.000000
# max      3.500000    6.000000             9.500000  113.000000   99.000000
#
#           cmb_mpg  greenhouse_gas_score
# count  328.000000            328.000000
# mean    30.411585              6.329268
# std     10.081539              1.410358
# min     25.000000              4.000000
# 25%     26.000000              5.000000
# 50%     28.000000              6.000000
# ...

# %%
pd.plotting.scatter_matrix(top_18,figsize=(15,15));
