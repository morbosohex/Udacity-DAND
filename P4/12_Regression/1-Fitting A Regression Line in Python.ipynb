# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

df = pd.read_csv('house_price_area_only.csv')
df.head()
# Out:
#    Unnamed: 0    price  area
# 0           0   598291  1188
# 1           1  1744259  3512
# 2           2   571669  1134
# 3           3   493675  1940
# 4           4  1101539  2208

# %%
df['intercept'] = 1
lm = sm.OLS(df['price'], df['area'])
results = lm.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.895
# Model:                            OLS   Adj. R-squared:                  0.895
# Method:                 Least Squares   F-statistic:                 5.152e+04
# Date:                Wed, 12 Sep 2018   Prob (F-statistic):               0.00
# Time:                        16:20:06   Log-Likelihood:                -84518.
# No. Observations:                6028   AIC:                         1.690e+05
# Df Residuals:                    6027   BIC:                         1.690e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# area         351.8265      1.550    226.980      0.000     348.788     354.865
# ...
